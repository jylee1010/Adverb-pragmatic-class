# %%
import nltk
from datasets import load_dataset
import pandas as pd
import spacy
import ahocorasick
import json

# %%
nlp = spacy.load("en_core_web_sm")

# %%
def sentence_split(batch):
    examples = {
        "sentence": [],
        "id": [],
    }
    for i, text in enumerate(batch["text"]):
        date = int(batch["dump"][i][8:12])
        for idx, sent in enumerate(nltk.sent_tokenize(text)):
            examples["sentence"].append(sent)
            examples["id"].append(batch["id"][i] + f"-{idx}")
    return examples

# %%
corpus = "open_subtitles"
lang1 = "en"
lang2 = "fr"

# %%
automaton = ahocorasick.Automaton()
with open("adv_ends_ly.txt") as adverbs:
    for idx, line in enumerate(adverbs.readlines()):
        line = line.strip()
        if not line.endswith("ly"):
            continue
        automaton.add_word(line, idx)

automaton.make_automaton()

# %%
data = load_dataset(corpus, lang1=lang1, lang2=lang2, split="train")
data = data.map(lambda x: {"english": x["translation"]["en"]})
# Out:
# Map:   0%|          | 0/41763488 [00:00<?, ? examples/s]

# %%
data[0]
# Out:
# {'id': '0',
#  'meta': {'year': 0,
#   'imdbId': 1089124,
#   'subtitleId': {'en': 4995691, 'fr': 4588599},
#   'sentenceIds': {'en': [1], 'fr': [1]}},
#  'translation': {'en': 'I never dreamed before',
#   'fr': "I've never dreamed before I'm gonna knock the door"},
#  'english': 'I never dreamed before'}

# %%
data = data.filter(lambda x:
                   sum([1 for end_index, val in automaton.iter(x["english"].lower())]) == 1, num_proc=4)
# Out:
# Filter (num_proc=4):   0%|          | 0/41763488 [00:00<?, ? examples/s]

# %%
print(data)
# Out:
# Dataset({
#     features: ['id', 'meta', 'translation', 'english'],
#     num_rows: 1691511
# })

# %%
data.to_parquet("all_adverbs.parquet")
# Out:
# Creating parquet from Arrow format:   0%|          | 0/56831 [00:00<?, ?ba/s]
# 12112775938

# %%
from datasets import Dataset

# Load the Parquet file back into a Hugging Face Dataset
data = Dataset.from_parquet("all_adverbs.parquet")
# Out:
# Loading dataset shards:   0%|          | 0/25 [00:00<?, ?it/s]

# %%
def get_adverb_position(doc):
    for token in doc:
        if token.pos_ == "ADV":
            head = token.head
            if head.pos_ == "VERB":
                if token.i == 0:
                    return "sentence-initial"
                elif token.i + 1 == head.i:
                    return "imediate-pre-verbal"
                elif token.i < head.i:
                    return "pre-verbal"
                elif token.i == head.i + 1:
                    return "imediate-pos-verbal"
                elif token.i > head.i:
                    return "post-verbal"
                else:
                    return "same-position"
            else:
                return "not-modifying-verb"
    return "no-adverb-found"

# %%
def classify_verb(token):
    lemma = token.lemma_.lower()

    communication_verbs = {
        "say", "tell", "ask", "speak", "talk", "mention", "report", "state", "argue", "explain",
        "describe", "suggest", "claim", "shout", "reply", "answer", "admit", "warn", "announce", "discuss"
        }
    transfer_verbs = {
        "give", "get", "take", "bring", "send", "offer", "receive", "buy", "sell", "pay",
        "lend", "borrow", "deliver", "return", "hand", "pass", "grant", "present", "allocate", "assign"
        }
    stative_verbs = {
        "be", "have", "know", "believe", "understand", "want", "need",
        "own", "belong", "seem", "appear", "mean", "contain", "include", "consist", "matter"
        }
    motion_verbs = {
        "go", "come", "walk", "run", "move", "travel", "drive", "fly", "ride", "swim",
        "jump", "climb", "crawl", "slide", "roll", "march", "leap", "hurry", "stroll", "wander"
        }
    psychological_verbs = {
        "like", "love", "hate", "enjoy", "prefer", "fear", "miss", "appreciate", "desire", "regret",
        "resent", "admire", "envy", "worry", "hope", "wish", "dread", "cherish", "value", "loathe"
        }
    perception_verbs = {
        "see", "hear", "feel", "smell", "taste", "notice", "recognize", "perceive", "detect", "observe",
        "look", "listen", "watch", "glance", "gaze", "stare", "peek", "peep", "scan", "spot"
        }

    if lemma in motion_verbs:
        return "motion"
    elif lemma in psychological_verbs:
        return "psychological"
    elif lemma in communication_verbs:
        return "communication"
    elif lemma in transfer_verbs:
        return "transfer"
    elif lemma in stative_verbs:
        return "stative"
    else:
        return "other"

def get_adverb_verb_class(doc):
    for token in doc:
        if token.pos_ == "ADV":
            head = token.head
            if head.pos_ == "VERB":
                return classify_verb(head)
    return "no_head_verb"

# %%
def get_sentence_mood(doc):
    if doc[-1].text == "?":
        return "interrogative"

    # Check for imperative (command)
    root = [token for token in doc if token.dep_ == "ROOT"]
    if root:
        root = root[0]
        # Imperatives often start with a verb in base form and have no subject
        if root.tag_ == "VB":  # base form verb
            has_subject = any(token.dep_ in ("nsubj", "nsubjpass") for token in doc)
            if not has_subject:
                return "imperative"

    # Otherwise, assume declarative
    return "declarative"

# %%
def get_comma_intonation_adverbs(doc):
    results = []
    for i, token in enumerate(doc[:-1]):  # Avoid out-of-range
        if token.pos_ == "ADV" and doc[i+1].text == ",":
            return True
    return False

# %%
def get_adverb_scope(doc):
    for token in doc:
        if token.pos_ == "ADV":
            head = token.head
            if head.dep_ == "ROOT":
                return "S"
            elif head.pos_ == "VERB":
                return "VP"
    return "unknown"

# %%
def get_adverb_text(doc):
    for token in doc:
        if token.pos_ == "ADV":
            return token.text

# %%
def get_adverb_count(doc):
    count = 0
    for token in doc:
        if token.pos_ == "ADV":
            count += 1
    return count

# %%
def get_subject_animacy(doc):
    for token in doc:
        if token.dep_ == "nsubj":
            if token.ent_type_ in ("PERSON", "ORG"): return "animate"
            if token.text.lower() in {"he", "she", "they", "i", "we"}: return "animate"
    return "inanimate"

# %%
def get_negation_scope(doc):
    for adv in doc:
        if adv.pos_ == "ADV":
            for neg in doc:
                if neg.dep_ == "neg":
                    return "neg_before_adv" if neg.i < adv.i else "adv_before_neg"
    return "no_negation"

# %%
def classify_adverb(token):
    lemma = token.lemma_.lower()

    temporal_adverbs = {
        "briefly", "soon", "later", "now", "yesterday", "today", "tomorrow", "already",
        "still", "recently", "eventually", "formerly", "instantly", "meanwhile", "afterward",
        "immediately", "lately", "presently", "shortly", "once", "then", "beforehand", "simultaneously"
    }
    locative_adverbs = {
        "here", "there", "everywhere", "somewhere", "anywhere", "abroad", "indoors", "outside", "home",
        "nearby", "above", "below", "upstairs", "downstairs", "overseas", "within", "underneath"
    }
    manner_adverbs = {
        "quickly", "carefully", "badly", "well", "happily", "sadly", "easily", "stupidly", "loudly", "safely",
        "calmly", "ardently", "correctly", "gracefully", "silently", "poorly", "angrily", "bravely", "clumsily",
        "gently", "neatly", "randomly"
    }
    degree_adverbs = {
        "very", "extremely", "somewhat", "too", "so", "barely", "highly", "totally", "completely", "exactly",
        "perfectly", "absolutely", "entirely", "deeply", "greatly", "moderately", "thoroughly", "almost", "hardly",
        "intensely"
    }
    frequency_adverbs = {
        "often", "sometimes", "rarely", "seldom", "always", "never", "occasionally", "frequently",
        "regularly", "usually", "hardly ever", "annually", "daily", "monthly", "hourly", "weekly"
    }
    epistemic_adverbs = {
        "possibly", "probably", "certainly", "surely", "undoubtedly", "maybe", "definitely", "clearly",
        "evidently", "presumably", "apparently", "conceivably", "seemingly", "likely", "arguably"
    }
    evaluative_adverbs = {
        "fortunately", "unfortunately", "surprisingly", "stupidly", "interestingly", "sadly", "hopefully", "honestly",
        "kindly", "politely", "quite", "frankly", "regrettably", "mercifully", "remarkably", "disappointingly",
        "amazingly", "tragically"
    }
    contrastive_adverbs = {
        "only", "just", "even", "also", "mainly", "mostly", "especially", "particularly",
        "however", "nevertheless", "nonetheless", "instead", "though", "still", "alternatively", "conversely"
    }

    if lemma in temporal_adverbs:
        return "temporal"
    elif lemma in locative_adverbs:
        return "locative"
    elif lemma in manner_adverbs:
        return "manner"
    elif lemma in degree_adverbs:
        return "degree"
    elif lemma in frequency_adverbs:
        return "frequency"
    elif lemma in epistemic_adverbs:
        return "epistemic"
    elif lemma in evaluative_adverbs:
        return "evaluative"
    elif lemma in contrastive_adverbs:
        return "contrastive"
    else:
        return "other"


def get_adverb_class(doc):
    for token in doc:
        if token.pos_ == "ADV":
            return classify_adverb(token)
    return "no_adverb"

# %%
def grammatical_features(examples):
    doc = nlp(examples['sentence'])
    return {
        "adverb_position": get_adverb_position(doc),
        "verb_class": get_adverb_verb_class(doc),
        "sentence_mood": get_sentence_mood(doc),
        "adverb_scope": get_adverb_scope(doc),
        "comma_intonation": get_comma_intonation_adverbs(doc),
        "adverb_text": get_adverb_text(doc),
        "adverb_count": get_adverb_count(doc),
        "subject_animacy": get_subject_animacy(doc),
        "negation_scope": get_negation_scope(doc),
        "lexical_adverb_category": get_adverb_class(doc),
    }

# %%
data_with_features = data.shuffle(seed=42).map(
    grammatical_features, num
    remove_columns=["id"]).filter(lambda x: x["adverb_position"] != "unknown")
# Out:
# Map:   0%|          | 0/56830279 [00:00<?, ? examples/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 data_with_features = data.shuffle(seed=42).map(
#       2     grammatical_features,
#       3     remove_columns=["id"]).filter(lambda x: x["adverb_position"] != "unknown")
#
# File ~/Projects/SemanticChangeType/venv/lib/python3.10/site-packages/datasets/arrow_dataset.py:560, in transmit_format.<locals>.wrapper(*args, **kwargs)
#     553 self_format = {
#     554     "type": self._format_type,
#     555     "format_kwargs": self._format_kwargs,
#     556     "columns": self._format_columns,
#     557     "output_all_columns": self._output_all_columns,
#     558 }
#     559 # apply actual function
# --> 560 out: Union["Dataset", "DatasetDict"] = func(self, *args, **kwargs)
#     561 datasets: List["Dataset"] = list(out.values()) if isinstance(out, dict) else [out]
#     562 # re-apply format to the output
#
# File ~/Projects/SemanticChangeType/venv/lib/python3.10/site-packages/datasets/arrow_dataset.py:3055, in Dataset.map(self, function, with_indices, with_rank, input_columns, batched, batch_size, drop_last_batch, remove_columns, keep_in_memory, load_from_cache_file, cache_file_name, writer_batch_size, features, disable_nullable, fn_kwargs, num_proc, suffix_template, new_fingerprint, desc)
#    3049 if transformed_dataset is None:
#    3050     with hf_tqdm(
#    3051         unit=" examples",
#    3052         total=pbar_total,
#    3053         desc=desc or "Map",
#    3054     ) as pbar:
# -> 3055         for rank, done, content in Dataset._map_single(**dataset_kwargs):
#    3056             if done:
#    3057                 shards_done += 1
#
# File ~/Projects/SemanticChangeType/venv/lib/python3.10/site-packages/datasets/arrow_dataset.py:3428, in Dataset._map_single(shard, function, with_indices, with_rank, input_columns, batched, batch_size, drop_last_batch, remove_columns, keep_in_memory, cache_file_name, writer_batch_size, features, disable_nullable, fn_kwargs, new_fingerprint, rank, offset)
#    3426 _time = time.time()
#    3427 for i, example in shard_iterable:
# -> 3428     example = apply_function_on_filtered_inputs(example, i, offset=offset)
#    3429     if update_data:
#    3430         if i == 0:
#
# File ~/Projects/SemanticChangeType/venv/lib/python3.10/site-packages/datasets/arrow_dataset.py:3320, in Dataset._map_single.<locals>.apply_function_on_filtered_inputs(pa_inputs, indices, check_same_num_examples, offset)
#    3318 if with_rank:
#    3319     additional_args += (rank,)
# -> 3320 processed_inputs = function(*fn_args, *additional_args, **fn_kwargs)
#    3321 if isinstance(processed_inputs, LazyDict):
#    3322     processed_inputs = {
#    3323         k: v for k, v in processed_inputs.data.items() if k not in processed_inputs.keys_to_format
#    3324     }
#
# Cell In[72], line 2, in grammatical_features(examples)
#       1 def grammatical_features(examples):
# ----> 2     doc = nlp(examples['sentence'])
#       3     return {
#       4         "adverb_position": get_adverb_position(doc),
#       5         "verb_class": get_adverb_verb_class(doc),
#    (...)
#      13         "lexical_adverb_category": get_adverb_class(doc),
#      14     }
#
# File ~/Projects/SemanticChangeType/venv/lib/python3.10/site-packages/spacy/language.py:1052, in Language.__call__(self, text, disable, component_cfg)
#    1050     error_handler = proc.get_error_handler()
#    1051 try:
# -> 1052     doc = proc(doc, **component_cfg.get(name, {}))  # type: ignore[call-arg]
#    1053 except KeyError as e:
#    1054     # This typically happens if a component is not initialized
#    1055     raise ValueError(Errors.E109.format(name=name)) from e
#
# File ~/Projects/SemanticChangeType/venv/lib/python3.10/site-packages/spacy/pipeline/trainable_pipe.pyx:52, in spacy.pipeline.trainable_pipe.TrainablePipe.__call__()
#
# File ~/Projects/SemanticChangeType/venv/lib/python3.10/site-packages/spacy/pipeline/tok2vec.py:126, in Tok2Vec.predict(self, docs)
#     124     width = self.model.get_dim("nO")
#     125     return [self.model.ops.alloc((0, width)) for doc in docs]
# --> 126 tokvecs = self.model.predict(docs)
#     127 return tokvecs
#
# File ~/Projects/SemanticChangeType/venv/lib/python3.10/site-packages/thinc/model.py:334, in Model.predict(self, X)
#     330 def predict(self, X: InT) -> OutT:
#     331     """Call the model's `forward` function with `is_train=False`, and return
#     332     only the output, instead of the `(output, callback)` tuple.
#     333     """
# --> 334     return self._func(self, X, is_train=False)[0]
#
# File ~/Projects/SemanticChangeType/venv/lib/python3.10/site-packages/thinc/layers/chain.py:54, in forward(model, X, is_train)
#      52 callbacks = []
#      53 for layer in model.layers:
# ---> 54     Y, inc_layer_grad = layer(X, is_train=is_train)
#      55     callbacks.append(inc_layer_grad)
#      56     X = Y
#
# File ~/Projects/SemanticChangeType/venv/lib/python3.10/site-packages/thinc/model.py:310, in Model.__call__(self, X, is_train)
#     307 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     308     """Call the model's `forward` function, returning the output and a
#     309     callback to compute the gradients via backpropagation."""
# --> 310     return self._func(self, X, is_train=is_train)
#
# File ~/Projects/SemanticChangeType/venv/lib/python3.10/site-packages/thinc/layers/chain.py:54, in forward(model, X, is_train)
#      52 callbacks = []
#      53 for layer in model.layers:
# ---> 54     Y, inc_layer_grad = layer(X, is_train=is_train)
#      55     callbacks.append(inc_layer_grad)
#      56     X = Y
#
# File ~/Projects/SemanticChangeType/venv/lib/python3.10/site-packages/thinc/model.py:310, in Model.__call__(self, X, is_train)
#     307 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     308     """Call the model's `forward` function, returning the output and a
#     309     callback to compute the gradients via backpropagation."""
# --> 310     return self._func(self, X, is_train=is_train)
#
# File ~/Projects/SemanticChangeType/venv/lib/python3.10/site-packages/thinc/layers/with_array.py:36, in forward(model, Xseq, is_train)
#      32 def forward(
#      33     model: Model[SeqT, SeqT], Xseq: SeqT, is_train: bool
#      34 ) -> Tuple[SeqT, Callable]:
#      35     if isinstance(Xseq, Ragged):
# ---> 36         return cast(Tuple[SeqT, Callable], _ragged_forward(model, Xseq, is_train))
#      37     elif isinstance(Xseq, Padded):
#      38         return cast(Tuple[SeqT, Callable], _padded_forward(model, Xseq, is_train))
#
# File ~/Projects/SemanticChangeType/venv/lib/python3.10/site-packages/thinc/layers/with_array.py:91, in _ragged_forward(model, Xr, is_train)
#      87 def _ragged_forward(
#      88     model: Model[SeqT, SeqT], Xr: Ragged, is_train: bool
#      89 ) -> Tuple[Ragged, Callable]:
#      90     layer: Model[ArrayXd, ArrayXd] = model.layers[0]
# ---> 91     Y, get_dX = layer(Xr.dataXd, is_train)
#      93     def backprop(dYr: Ragged) -> Ragged:
#      94         return Ragged(get_dX(dYr.dataXd), dYr.lengths)
#
# File ~/Projects/SemanticChangeType/venv/lib/python3.10/site-packages/thinc/model.py:310, in Model.__call__(self, X, is_train)
#     307 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     308     """Call the model's `forward` function, returning the output and a
#     309     callback to compute the gradients via backpropagation."""
# --> 310     return self._func(self, X, is_train=is_train)
#
# File ~/Projects/SemanticChangeType/venv/lib/python3.10/site-packages/thinc/layers/chain.py:54, in forward(model, X, is_train)
#      52 callbacks = []
#      53 for layer in model.layers:
# ---> 54     Y, inc_layer_grad = layer(X, is_train=is_train)
#      55     callbacks.append(inc_layer_grad)
#      56     X = Y
#
# File ~/Projects/SemanticChangeType/venv/lib/python3.10/site-packages/thinc/model.py:310, in Model.__call__(self, X, is_train)
#     307 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     308     """Call the model's `forward` function, returning the output and a
#     309     callback to compute the gradients via backpropagation."""
# --> 310     return self._func(self, X, is_train=is_train)
#
# File ~/Projects/SemanticChangeType/venv/lib/python3.10/site-packages/thinc/layers/chain.py:54, in forward(model, X, is_train)
#      52 callbacks = []
#      53 for layer in model.layers:
# ---> 54     Y, inc_layer_grad = layer(X, is_train=is_train)
#      55     callbacks.append(inc_layer_grad)
#      56     X = Y
#
# File ~/Projects/SemanticChangeType/venv/lib/python3.10/site-packages/thinc/model.py:310, in Model.__call__(self, X, is_train)
#     307 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     308     """Call the model's `forward` function, returning the output and a
#     309     callback to compute the gradients via backpropagation."""
# --> 310     return self._func(self, X, is_train=is_train)
#
# File ~/Projects/SemanticChangeType/venv/lib/python3.10/site-packages/thinc/layers/maxout.py:52, in forward(model, X, is_train)
#      50 W = model.get_param("W")
#      51 W = model.ops.reshape2f(W, nO * nP, nI)
# ---> 52 Y = model.ops.gemm(X, W, trans2=True)
#      53 Y += model.ops.reshape1f(b, nO * nP)
#      54 Z = model.ops.reshape3f(Y, Y.shape[0], nO, nP)
#
# KeyboardInterrupt:

# %%
data_with_features
# Out:
# Dataset({
#     features: ['sentence', 'adverb_position', 'verb_class', 'sentence_mood', 'adverb_scope', 'comma_intonation', 'adverb_text', 'adverb_count', 'subject_animacy', 'negation_scope'],
#     num_rows: 94494
# })

# %%
pandas_data = data_with_features.to_pandas()

# %%
pandas_data.head()
# Out:
#                                             sentence adverb_position  \
# 0  In the 1901 annual report of the Commissioner ...     post-verbal
# 1  By the early 20th century, however, it had bec...            None
# 2  For Esther to invite the king for a private me...            None
# 3  Vitamin A has directly involvement in the prod...     post-verbal
# 4  Comparing today’s current extinction crisis wi...     post-verbal
#
#      verb_class sentence_mood adverb_scope  comma_intonation adverb_text  \
# 0         other   declarative           VP             False        only
# 1         other   declarative            S              True     however
# 2         other   declarative           VP             False        also
# 3  no_head_verb   declarative      unknown             False    directly
# 4  no_head_verb   declarative      unknown             False  ultimately
#
#    adverb_count subject_animacy negation_scope
# 0             1       inanimate    no_negation
# 1             2       inanimate    no_negation
# 2             2         animate    no_negation
# 3             1       inanimate    no_negation
# 4             1       inanimate    no_negation

# %%
# pandas_data = pd.get_dummies(
#     pandas_data,
#     columns=["adverb_position", "adverb_class", "has_negation", "sentence_mood", "adverb_scope"],
#     drop_first=True)

# %%
pandas_data.head()
# Out:
#                                             sentence adverb_position  \
# 0  In the 1901 annual report of the Commissioner ...     post-verbal
# 1  By the early 20th century, however, it had bec...            None
# 2  For Esther to invite the king for a private me...            None
# 3  Vitamin A has directly involvement in the prod...     post-verbal
# 4  Comparing today’s current extinction crisis wi...     post-verbal
#
#      verb_class sentence_mood adverb_scope  comma_intonation adverb_text  \
# 0         other   declarative           VP             False        only
# 1         other   declarative            S              True     however
# 2         other   declarative           VP             False        also
# 3  no_head_verb   declarative      unknown             False    directly
# 4  no_head_verb   declarative      unknown             False  ultimately
#
#    adverb_count subject_animacy negation_scope
# 0             1       inanimate    no_negation
# 1             2       inanimate    no_negation
# 2             2         animate    no_negation
# 3             1       inanimate    no_negation
# 4             1       inanimate    no_negation

# %%
pandas_data.to_csv("all_adverbs_in_context.csv", index=False)

# %%
feature_columns = pandas_data.columns.tolist()
feature_columns.remove("sentence")

# 2. Drop duplicate combinations
unique_feature_rows = pandas_data.drop_duplicates(subset=feature_columns)

# %%
unique_feature_rows.to_csv("adverbs_in_context.csv", sep="\t", index=False)

# %%
unique_feature_rows
# Out:
#                                                 sentence   adverb_position  \
# 0      In the 1901 annual report of the Commissioner ...       post-verbal
# 1      By the early 20th century, however, it had bec...              None
# 2      For Esther to invite the king for a private me...              None
# 3      Vitamin A has directly involvement in the prod...       post-verbal
# 4      Comparing today’s current extinction crisis wi...       post-verbal
# ...                                                  ...               ...
# 94472  In the second column, write down what you do (...       post-verbal
# 94477  Fortunately, Michael Lane of the CDC, who work...  sentence-initial
# 94484  The dust size and shape are obviously independ...              None
# 94486  😩\nDue to the abundance of word problems, I've...              None
# 94488  When he says “Thou hast it now” he is saying, ...       post-verbal
#
#           verb_class sentence_mood adverb_scope  comma_intonation  \
# 0              other   declarative           VP             False
# 1              other   declarative            S              True
# 2              other   declarative           VP             False
# 3       no_head_verb   declarative      unknown             False
# 4       no_head_verb   declarative      unknown             False
# ...              ...           ...          ...               ...
# 94472          other   declarative           VP              True
# 94477          other   declarative           VP              True
# 94484          other   declarative            S             False
# 94486   no_head_verb   declarative      unknown             False
# 94488  communication   declarative            S             False
#
#        adverb_text  adverb_count subject_animacy  negation_scope
# 0             only             1       inanimate     no_negation
# 1          however             2       inanimate     no_negation
# 2             also             2         animate     no_negation
# 3         directly             1       inanimate     no_negation
# 4       ultimately             1       inanimate     no_negation
# ...            ...           ...             ...             ...
# 94472   conversely             1       inanimate  adv_before_neg
# 94477  Fortunately             1         animate  adv_before_neg
# 94484    obviously             2       inanimate     no_negation
# 94486         very             2         animate  neg_before_adv
# 94488          now             2         animate  adv_before_neg
#
# [33048 rows x 10 columns]

# %%
interest = ahocorasick.Automaton() 
with open("words_of_interest.txt") as adverbs:
    for idx, line in enumerate(adverbs.readlines()):
        line = line.strip()
        interest.add_word(line, idx)

interest.make_automaton()

# %%
words_of_interest = pandas_data[pandas_data.apply(
    lambda x: x['adverb_count'] == 1 and sum([1 for end_index, val in interest.iter(x["sentence"].lower())]) == 1 and not x['sentence'].lower().startswith("if")
, axis=1)].drop_duplicates(subset=feature_columns)

# %%
words_of_interest.to_csv("woi_adverbs.csv", sep="\t", index=False)

# %%
words_of_interest
# Out:
#                                                 sentence   adverb_position  \
# 61     It has honestly become quite a chore to do any...        pre-verbal
# 204    For extra information on essential oils kindly...        pre-verbal
# 452    Adding humus to the soil and using mulch gener...              None
# 1328   I am called upon to sing of the Parilia, and n...       post-verbal
# 1781   I honestly doubt, yojana has changed its defin...              None
# ...                                                  ...               ...
# 92364  (“The Path of the Righteous” – “Mesillas Yesha...       post-verbal
# 92986  Asimov was one of the most prolific writers of...       post-verbal
# 93723  The problem of mending or ending industrialism...              None
# 93933  Wisely placed lawn ornaments in the landscape ...  sentence-initial
# 94011  Determinants & Inverse Matrices Math Lib: This...              None
#
#           verb_class sentence_mood adverb_scope  comma_intonation  \
# 61             other   declarative            S             False
# 204            other   declarative            S             False
# 452            other    imperative           VP             False
# 1328           other   declarative           VP             False
# 1781           other   declarative           VP             False
# ...              ...           ...          ...               ...
# 92364          other   declarative           VP             False
# 92986  communication   declarative            S             False
# 93723          other   declarative           VP             False
# 93933          other   declarative           VP             False
# 94011   no_head_verb   declarative      unknown             False
#
#        adverb_text  adverb_count subject_animacy  negation_scope
# 61        honestly             1       inanimate     no_negation
# 204         kindly             1       inanimate     no_negation
# 452     generously             1       inanimate     no_negation
# 1328        kindly             1       inanimate  neg_before_adv
# 1781      honestly             1         animate     no_negation
# ...            ...           ...             ...             ...
# 92364       humbly             1       inanimate     no_negation
# 92986  reluctantly             1         animate     no_negation
# 93723    foolishly             1       inanimate     no_negation
# 93933       Wisely             1       inanimate     no_negation
# 94011     honestly             1       inanimate     no_negation
#
# [149 rows x 10 columns]

# %%
manner = pd.read_csv("subori.csv")

# %%
manner
# Out:
#                                               sentence    adverb_text  \
# 0    Prepare for an honest conversation with your k...       honestly
# 1    But what exactly sparked the rise of the holis...        exactly
# 2               Clearly, Larry is a power-hungry jerk.        Clearly
# 3              Unfortunately, it isnt a simple answer.  Unfortunately
# 4                       Unfortunately, it didn’t work.  Unfortunately
# ..                                                 ...            ...
# 251  “(Gilmore, Smith 31) God needs his followers t...     obediently
# 252  The woman in blue listens to the discussion ta...      passively
# 253  They did not expect to have an opening in the ...             so
# 254  At a book reading he gave in Washington, sever...        angrily
# 255  The eagerly-expected explanations of Lord Palm...        eagerly
#
#     lexical_adverb_category   adverb_type      adverb_position    verb_class  \
# 0                evaluative        manner   not-modifying-verb  no_head_verb
# 1                     other  context-free   not-modifying-verb  no_head_verb
# 2                     modal  context-free   not-modifying-verb  no_head_verb
# 3                evaluative  context-free   not-modifying-verb  no_head_verb
# 4                evaluative  context-free   not-modifying-verb  no_head_verb
# ..                      ...           ...                  ...           ...
# 251                   other        manner  imediate-pre-verbal         other
# 252                   other        manner  imediate-pos-verbal         other
# 253                  degree  context-free           pre-verbal        motion
# 254                   other        manner  imediate-pre-verbal         other
# 255                   other        manner           pre-verbal         other
#
#      negation_scope  sentence_mood adverb_scope  comma_intonation  \
# 0       no_negation     imperative      unknown             False
# 1       no_negation  interrogative      unknown             False
# 2       no_negation    declarative            S              True
# 3    adv_before_neg    declarative            S              True
# 4       no_negation    declarative      unknown              True
# ..              ...            ...          ...               ...
# 251     no_negation    declarative           VP             False
# 252     no_negation    declarative           VP             False
# 253  neg_before_adv    declarative           VP             False
# 254     no_negation    declarative            S             False
# 255     no_negation    declarative           VP             False
#
#     subject_animacy
# 0         inanimate
# 1         inanimate
# 2           animate
# 3         inanimate
# 4         inanimate
# ..              ...
# 251       inanimate
# 252       inanimate
# 253         animate
# 254         animate
# 255       inanimate
#
# [256 rows x 11 columns]

# %%
manner.sentence = manner.sentence.str.replace("<mark>", "")
manner.sentence = manner.sentence.str.replace("</mark>", "")
manner.sentence = manner.sentence.str.replace("\n", "").replace("\r", "")
manner
# Out:
#                                               sentence    adverb_text  \
# 0    Prepare for an honest conversation with your k...       honestly
# 1    But what exactly sparked the rise of the holis...        exactly
# 2               Clearly, Larry is a power-hungry jerk.        Clearly
# 3              Unfortunately, it isnt a simple answer.  Unfortunately
# 4                       Unfortunately, it didn’t work.  Unfortunately
# ..                                                 ...            ...
# 251  “(Gilmore, Smith 31) God needs his followers t...     obediently
# 252  The woman in blue listens to the discussion ta...      passively
# 253  They did not expect to have an opening in the ...             so
# 254  At a book reading he gave in Washington, sever...        angrily
# 255  The eagerly-expected explanations of Lord Palm...        eagerly
#
#     lexical_adverb_category   adverb_type      adverb_position    verb_class  \
# 0                evaluative        manner   not-modifying-verb  no_head_verb
# 1                     other  context-free   not-modifying-verb  no_head_verb
# 2                     modal  context-free   not-modifying-verb  no_head_verb
# 3                evaluative  context-free   not-modifying-verb  no_head_verb
# 4                evaluative  context-free   not-modifying-verb  no_head_verb
# ..                      ...           ...                  ...           ...
# 251                   other        manner  imediate-pre-verbal         other
# 252                   other        manner  imediate-pos-verbal         other
# 253                  degree  context-free           pre-verbal        motion
# 254                   other        manner  imediate-pre-verbal         other
# 255                   other        manner           pre-verbal         other
#
#      negation_scope  sentence_mood adverb_scope  comma_intonation  \
# 0       no_negation     imperative      unknown             False
# 1       no_negation  interrogative      unknown             False
# 2       no_negation    declarative            S              True
# 3    adv_before_neg    declarative            S              True
# 4       no_negation    declarative      unknown              True
# ..              ...            ...          ...               ...
# 251     no_negation    declarative           VP             False
# 252     no_negation    declarative           VP             False
# 253  neg_before_adv    declarative           VP             False
# 254     no_negation    declarative            S             False
# 255     no_negation    declarative           VP             False
#
#     subject_animacy
# 0         inanimate
# 1         inanimate
# 2           animate
# 3         inanimate
# 4         inanimate
# ..              ...
# 251       inanimate
# 252       inanimate
# 253         animate
# 254         animate
# 255       inanimate
#
# [256 rows x 11 columns]

# %%
man = manner[["sentence", "adverb_type"]].join(manner.apply(grammatical_features, axis=1).apply(pd.Series))

# %%
man = man.apply(lambda x: x.str.replace('\n', ' ').replace('\r', ' ') if isinstance(x, str) else x)

# %%
man.to_csv("subori.csv", sep="\t", index=False)

# %%
manner = pd.read_csv("subori.csv")
manner
# Out:
#                                                sentence   adverb_type  \
# 0     Prepare for an honest conversation with your k...        manner
# 1     But what exactly sparked the rise of the holis...  context-free
# 2                Clearly, Larry is a power-hungry jerk.  context-free
# 3               Unfortunately, it isnt a simple answer.  context-free
# 4                        Unfortunately, it didn’t work.  context-free
# ...                                                 ...           ...
# 1860  But meantime a French brigade had driven von d...           NaN
# 1861  I see no greatness, nor any kind of superiorit...           NaN
# 1862  A possible and fairly common example is this: ...           NaN
# 1863  This strategy has been used in recent years fo...           NaN
# 1864  (2) Although the third and fourth paradigms of...           NaN
#
#           adverb_position    verb_class  sentence_mood adverb_scope  \
# 0      not-modifying-verb  no_head_verb     imperative      unknown
# 1      not-modifying-verb  no_head_verb  interrogative      unknown
# 2      not-modifying-verb  no_head_verb    declarative            S
# 3      not-modifying-verb  no_head_verb    declarative            S
# 4      not-modifying-verb  no_head_verb    declarative      unknown
# ...                   ...           ...            ...          ...
# 1860           pre-verbal        motion    declarative            S
# 1861   not-modifying-verb  no_head_verb    declarative      unknown
# 1862   not-modifying-verb         other    declarative           VP
# 1863  imediate-pos-verbal        motion    declarative           VP
# 1864  imediate-pre-verbal         other    declarative           VP
#
#       comma_intonation    adverb_text  adverb_count subject_animacy  \
# 0                False       honestly             1       inanimate
# 1                False        exactly             1       inanimate
# 2                 True        Clearly             1         animate
# 3                 True  Unfortunately             1       inanimate
# 4                 True  Unfortunately             1       inanimate
# ...                ...            ...           ...             ...
# 1860             False       meantime             3         animate
# 1861             False     peculiarly             2         animate
# 1862             False         fairly             2         animate
# 1863             False         slower             2       inanimate
# 1864             False         mately             2         animate
#
#       negation_scope lexical_adverb_category
# 0        no_negation              evaluative
# 1        no_negation                   other
# 2        no_negation                   modal
# 3     adv_before_neg              evaluative
# 4        no_negation              evaluative
# ...              ...                     ...
# 1860     no_negation                   other
# 1861     no_negation                   other
# 1862     no_negation                   other
# 1863     no_negation                   other
# 1864     no_negation                   other
#
# [1865 rows x 12 columns]
